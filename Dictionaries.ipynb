# %%
student ={

    "name":"Raju",
    "age":22,
    "city":"Chennai"
    }


print(student)
print(student["name"])
print(student.get("name"))
# Out:
# {'name': 'Raju', 'age': 22, 'city': 'Chennai'}
# Raju
# Raju
