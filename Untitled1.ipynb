# %%
n =10.5
if type(n) ==int :
    print("Integer")
elif type(n) == float:
    print("Float")
# Out:
# Float

# %%
list = [1,2,3,4,55,66,77,989]

print("Max Number:",max(list))
print("Min Number:",min(list))
# Out:
# Max Number: 989
# Min Number: 1

# %%
a=[1,2,3,4,5,5,5]
print(len(a))
print(a.count(5))
print(a.count(1))
# Out:
# 7
# 3
# 1

# %%
num = [1,2,3,4,5]
b = num[::-2]
print(b)
# Out:
# [5, 3, 1]

# %%
a=10
b=7
print(a+b)
c=a+b
print(c)
# Out:
# 17
# 17

# %%
a=[5,5,7,7,88,99,100]
total= sum(a)
print("total :",total)

avg = sum(a)/len(a)
print("Average : ",avg)
# Out:
# total : 311
# Average :  44.42857142857143

# %%
items = ["apple",22,"banana",44,"eggs","Chicken",0.77]

for i in items:
    if type(i)==str:
        print(i)
# Out:
# apple
# banana
# eggs
# Chicken

# %%
year=int(input("Enter a Year"))
if(year%4==0 and year %100!=0) or (year%400==0):
     print(year,"leap year")
else:
     print(year,"not an leap year")
# Out:
# Enter a Year 2003
# 2003 not an leap year

# %%
Age = int(input("Enter a age"))
student =(input("Enter a Yes or No")).lower()

if Age<5 :
  print("ticket is free")
elif Age<12:
  print("Ticket price is $10")
elif Age<17 :
    if(student=="Yes"):
       print("Ticket Price is $12")
    else:
       print("Ticket Price is $5")
elif Age<=64:
    if(student=="Yes"):
      print("Ticket price is $18")
    else :
      print("Ticket price is $25")
else:
    print("Ticket price is $20")
# Out:
# Enter a age 12
# Enter a Yes or No Yes
# Ticket Price is $5

# %%
n=5
for i in range(n):
 for j in range(n):
    print('*',end=' ')
 print()
# Out:
# * * * * *
# * * * * *
# * * * * *
# * * * * *
# * * * * *

# %%
n=5
for i in range(n):
  for j in range(i+1):
        print('*',end=' ')
  print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
n=5
for i in range(n):
 for j in range(i,n):
    print('*',end=' ')
 print()
# Out:
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
n=5
for i in range(n):
   for j in range(i,n):
     print(' ',end='')
   for j in range(i+1):
     print('*',end=' ')
   print()
# Out:
#      *
#     * *
#    * * *
#   * * * *
#  * * * * *

# %%
n = 10

for i in range(n):
    for j in range(i,n):
        print("*", end = " ")
    print()
# Out:
# * * * * * * * * * *
# * * * * * * * * *
# * * * * * * * *
# * * * * * * *
# * * * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
n = 10

for i in range(n):
    for j in range(i,n):
        print(" ", end = " ")
    for j in range(i):
        print("*", end = " ")
    print()
# Out:
#
#                   *
#                 * *
#               * * *
#             * * * *
#           * * * * *
#         * * * * * *
#       * * * * * * *
#     * * * * * * * *
#   * * * * * * * * *

# %%
n = 10

for i in range(n):
    for j in range(i,n):
        print(" ", end = " ")
    for j in range(i):
        print("*", end = " ")
    for j in range(i + 1 ):
        print("*", end = " ")

    print()
# Out:
#                     *
#                   * * *
#                 * * * * *
#               * * * * * * *
#             * * * * * * * * *
#           * * * * * * * * * * *
#         * * * * * * * * * * * * *
#       * * * * * * * * * * * * * * *
#     * * * * * * * * * * * * * * * * *
#   * * * * * * * * * * * * * * * * * * *

# %%
n = 10

for i in range(n):
    for j in range(i):
        print(" ", end = " ")
    for j in range(i,n):
        print("*", end = " ")
    for j in range(i,n ):
        print("*", end = " ")

    print()
# Out:
# * * * * * * * * * * * * * * * * * * * *
#   * * * * * * * * * * * * * * * * * *
#     * * * * * * * * * * * * * * * *
#       * * * * * * * * * * * * * *
#         * * * * * * * * * * * *
#           * * * * * * * * * *
#             * * * * * * * *
#               * * * * * *
#                 * * * *
#                   * *

# %%
n=10

for i in range(n):
    for j in range(i):
        print("*",end=" ")
    for j in range(i,n):
        print(" ",end=" ")
    for j in range(i,n):
        print(" ",end=" ")
    for j in range(i):
        print("*",end=" ")
    print()


for i in range(n):
    for j in range(i ,n):
        print("*",end=" ")
    for j in range(i ):
        print(" ",end=" ")
    for j in range(i ):
        print(" ",end=" ")
    for j in range(i ,n ):
        print("*",end=" ")
        
    print()
# Out:
#
# *                                     *
# * *                                 * *
# * * *                             * * *
# * * * *                         * * * *
# * * * * *                     * * * * *
# * * * * * *                 * * * * * *
# * * * * * * *             * * * * * * *
# * * * * * * * *         * * * * * * * *
# * * * * * * * * *     * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * *     * * * * * * * * *
# * * * * * * * *         * * * * * * * *
# * * * * * * *             * * * * * * *
# * * * * * *                 * * * * * *
# * * * * *                     * * * * *
# * * * *                         * * * *
# * * *                             * * *
# * *                                 * *
# *                                     *
